# %% [markdown]
# # Breast_Cancer_Detection

# %% [markdown]
# Import libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Load the dataset

# %% [markdown]
# Adjust the path to your CSV file

# %%
path=r"C:\Users\QFAROOQU\Downloads\breast-cancer.csv"
df = pd.read_csv(path)

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# Drop the 'id' column and encode 'diagnosis'

# %%
df = df.drop(columns=['id'])
df['diagnosis'] = df['diagnosis'].map({'M': 0, 'B': 1})  # 0 for malignant, 1 for benign

# %% [markdown]
# Define features and target

# %%
X = df.drop(columns=['diagnosis'])
y = df['diagnosis']

# %% [markdown]
# Split the data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2020)

# %% [markdown]
# Initialize and train the Decision Tree model

# %%
classifier = DecisionTreeClassifier(criterion='gini')
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# Evaluate the model

# %%
print("Model accuracy:", classifier.score(X_test, y_test))
# Out:
# Model accuracy: 0.9473684210526315

# %% [markdown]
#  Feature Scaling

# %%
sc = StandardScaler()
X_train_sc = sc.fit_transform(X_train)
X_test_sc = sc.transform(X_test)

# %% [markdown]
# Train with scaled features

# %%
classifier_sc = DecisionTreeClassifier(criterion='gini')
classifier_sc.fit(X_train_sc, y_train)
print("Scaled model accuracy:", classifier_sc.score(X_test_sc, y_test))
# Out:
# Scaled model accuracy: 0.9385964912280702

# %% [markdown]
# Predicting for a new patient

# %% [markdown]
# Create a DataFrame for the new patient with the same feature names

# %%
patient_data = {
    'radius_mean': [17.99], 'texture_mean': [10.38], 'perimeter_mean': [122.80], 'area_mean': [1001.0],
    'smoothness_mean': [0.1184], 'compactness_mean': [0.2776], 'concavity_mean': [0.3001], 'concave points_mean': [0.1471],
    'radius_se': [0.2654], 'texture_se': [0.0869], 'perimeter_se': [1.095], 'area_se': [0.9053],
    'smoothness_se': [0.006399], 'compactness_se': [0.04904], 'concavity_se': [0.05373], 'concave points_se': [0.01587],
    'radius_worst': [25.38], 'texture_worst': [17.33], 'perimeter_worst': [184.60], 'area_worst': [2019.0],
    'smoothness_worst': [0.1622], 'compactness_worst': [0.6656], 'concavity_worst': [0.7119], 'concave points_worst': [0.2654],
    'symmetry_worst': [0.4601], 'fractal_dimension_worst': [0.1189]
}
patient1 = pd.DataFrame(patient_data, columns=X.columns)

# %% [markdown]
# Predict

# %%
pred = classifier.predict(patient1)

# %% [markdown]
# Decode the prediction

# %%
pred_label = 'M' if pred[0] == 0 else 'B'
print(f'Prediction for patient: {pred_label}')
# Out:
# Prediction for patient: M
